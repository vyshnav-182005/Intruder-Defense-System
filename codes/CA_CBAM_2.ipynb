# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import os

# Cross Attention Module 
class CrossAttention(nn.Module):
    def __init__(self, dim, num_heads=4):
        super(CrossAttention, self).__init__()
        self.num_heads = num_heads
        self.scale = (dim // num_heads) ** -0.5
        self.qkv = nn.Linear(dim, dim * 3, bias=False)
        self.proj = nn.Linear(dim, dim)

    def forward(self, x1, x2):
        B, C, H, W = x1.shape
        x1 = x1.flatten(2).permute(0, 2, 1)
        x2 = x2.flatten(2).permute(0, 2, 1)

        qkv1 = self.qkv(x1).chunk(3, dim=-1)
        qkv2 = self.qkv(x2).chunk(3, dim=-1)

        q, k, v = qkv1[0], qkv2[1], qkv2[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        out = attn @ v

        out = self.proj(out)
        out = out.permute(0, 2, 1).reshape(B, C, H, W)
        return out
    
# Attention Blocks 
class ChannelAttention(nn.Module):
    def __init__(self, in_channels):
        super(ChannelAttention, self).__init__()
        self.cross_attention = CrossAttention(in_channels)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        ca_out = self.cross_attention(x, x)
        return self.sigmoid(ca_out) * x

class SpatialAttention(nn.Module):
    def __init__(self, in_channels):
        super(SpatialAttention, self).__init__()
        self.cross_attention = CrossAttention(in_channels)
        self.conv = nn.Conv2d(in_channels, 1, kernel_size=7, padding=3)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        sa_out = self.cross_attention(x, x)
        sa_out = self.conv(sa_out)
        return self.sigmoid(sa_out) * x

class CA_CBAM(nn.Module):
    def __init__(self, in_channels):
        super(CA_CBAM, self).__init__()
        self.channel_att = ChannelAttention(in_channels)
        self.spatial_att = SpatialAttention(in_channels)

    def forward(self, x):
        x = x * self.channel_att(x)
        x = x * self.spatial_att(x)
        return x

# Model Definition 
class FaceRecognitionModel(nn.Module):
    def __init__(self, num_classes):
        super(FaceRecognitionModel, self).__init__()
        self.backbone = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Dropout(0.3),

            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Dropout(0.3),

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Dropout(0.4),

            CA_CBAM(128),
            nn.AdaptiveAvgPool2d(1)
        )
        self.dropout = nn.Dropout(0.5)
        self.fc = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.backbone(x)
        x = x.view(x.size(0), -1)
        x = self.dropout(x)
        x = self.fc(x)
        return x

# Model Checkpoint Class
class ModelCheckpoint:
    def __init__(self, filepath, monitor='val_acc', save_best_only=True, mode='max'):
        self.filepath = filepath
        self.monitor = monitor
        self.save_best_only = save_best_only
        self.mode = mode
        self.best = float('-inf') if mode == 'max' else float('inf')

    def __call__(self, current, epoch, model, optimizer):
        is_better = (current > self.best) if self.mode == 'max' else (current < self.best)
        if self.save_best_only and not is_better:
            return
        self.best = current
        checkpoint = {
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            self.monitor: current
        }
        torch.save(checkpoint, self.filepath)
        print(f"✅ Checkpoint saved at epoch {epoch + 1} with {self.monitor}: {current:.2f}%")

# Dataset & DataLoader
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

dataset_path = r'D:\Projects\Sentinel turret rover\Data\4Class_Data_split'
train_dataset = datasets.ImageFolder(root=os.path.join(dataset_path, "train"), transform=transform)
test_dataset = datasets.ImageFolder(root=os.path.join(dataset_path, "test"), transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Evaluation Function
def evaluate(model, loader, device, criterion):
    model.eval()
    correct = 0
    total = 0
    total_loss = 0.0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            total_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
    acc = 100 * correct / total
    avg_loss = total_loss / len(loader)
    return acc, avg_loss


# Validation Function
def validate_model(model, test_loader, device, criterion):
    test_acc, test_loss = evaluate(model, test_loader, device, criterion)
    print(f"Final Test Accuracy of Best Model: {test_acc:.2f}%")
    print(f"Final Test Loss of Best Model: {test_loss:.4f}")


# Training Function with Checkpoint
def train_model(model, train_loader, test_loader, num_epochs=10, lr=0.001,
                save_path=r'D:\Projects\Sentinel turret rover\model\CA_CBAM_2.pth'):

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

    checkpoint = ModelCheckpoint(filepath=save_path, monitor='val_acc', save_best_only=True, mode='max')
    train_losses, val_losses = [], []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_acc = 100 * correct / total
        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        val_acc, val_loss = evaluate(model, test_loader, device, criterion)
        val_losses.append(val_loss)

        print(f"Epoch [{epoch + 1}/{num_epochs}]")
        print(f"  Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%")
        print(f"  Val   Loss: {val_loss:.4f}, Val   Acc: {val_acc:.2f}%")

        checkpoint(val_acc, epoch, model, optimizer)

    # Plot Training & Validation Loss
    plt.figure(figsize=(8, 5))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.title('Training & Validation Loss Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # Load best model
    print("\nLoading best model for final validation...")
    model.load_state_dict(torch.load(save_path)['model_state_dict'])
    validate_model(model, test_loader, device, criterion)


# Main Execution 
if __name__ == "__main__":
    model = FaceRecognitionModel(num_classes=len(train_dataset.classes))
    train_model(model, train_loader, test_loader, num_epochs=100, lr=0.001)
# Out:
# Epoch [1/100]
#   Train Loss: 1.1839, Train Acc: 48.00%
#   Val   Loss: 1.4870, Val   Acc: 40.00%
# ✅ Checkpoint saved at epoch 1 with val_acc: 40.00%
# Epoch [2/100]
#   Train Loss: 0.9685, Train Acc: 62.12%
#   Val   Loss: 1.6239, Val   Acc: 60.00%
# ✅ Checkpoint saved at epoch 2 with val_acc: 60.00%
# Epoch [3/100]
#   Train Loss: 0.8681, Train Acc: 68.75%
#   Val   Loss: 1.1192, Val   Acc: 65.00%
# ✅ Checkpoint saved at epoch 3 with val_acc: 65.00%
# Epoch [4/100]
#   Train Loss: 0.7770, Train Acc: 68.75%
#   Val   Loss: 1.0011, Val   Acc: 62.50%
# Epoch [5/100]
#   Train Loss: 0.7423, Train Acc: 69.75%
#   Val   Loss: 0.9187, Val   Acc: 65.00%
# Epoch [6/100]
#   Train Loss: 0.6745, Train Acc: 72.12%
#   Val   Loss: 0.8618, Val   Acc: 75.00%
# ✅ Checkpoint saved at epoch 6 with val_acc: 75.00%
# Epoch [7/100]
#   Train Loss: 0.6457, Train Acc: 75.38%
#   Val   Loss: 0.8695, Val   Acc: 75.00%
# Epoch [8/100]
#   Train Loss: 0.6023, Train Acc: 76.38%
#   Val   Loss: 0.8435, Val   Acc: 75.00%
# Epoch [9/100]
#   Train Loss: 0.5263, Train Acc: 80.88%
#   Val   Loss: 1.0046, Val   Acc: 67.50%
# Epoch [10/100]
#   Train Loss: 0.5418, Train Acc: 79.25%
#   Val   Loss: 0.9136, Val   Acc: 72.50%
# Epoch [11/100]
#   Train Loss: 0.4781, Train Acc: 82.88%
#   Val   Loss: 0.8297, Val   Acc: 75.00%
# Epoch [12/100]
#   Train Loss: 0.4267, Train Acc: 84.88%
#   Val   Loss: 0.6258, Val   Acc: 85.00%
# ✅ Checkpoint saved at epoch 12 with val_acc: 85.00%
# Epoch [13/100]
#   Train Loss: 0.3899, Train Acc: 87.38%
#   Val   Loss: 0.7183, Val   Acc: 77.50%
# Epoch [14/100]
#   Train Loss: 0.4186, Train Acc: 86.12%
#   Val   Loss: 0.8362, Val   Acc: 80.00%
# Epoch [15/100]
#   Train Loss: 0.3784, Train Acc: 87.00%
#   Val   Loss: 0.7004, Val   Acc: 70.00%
# Epoch [16/100]
#   Train Loss: 0.3809, Train Acc: 85.25%
#   Val   Loss: 0.6531, Val   Acc: 77.50%
# Epoch [17/100]
#   Train Loss: 0.3288, Train Acc: 87.62%
#   Val   Loss: 0.7254, Val   Acc: 80.00%
# Epoch [18/100]
#   Train Loss: 0.3398, Train Acc: 87.25%
#   Val   Loss: 0.6522, Val   Acc: 77.50%
# Epoch [19/100]
#   Train Loss: 0.3068, Train Acc: 89.50%
#   Val   Loss: 0.5736, Val   Acc: 80.00%
# Epoch [20/100]
#   Train Loss: 0.2780, Train Acc: 90.38%
#   Val   Loss: 0.5331, Val   Acc: 82.50%
# Epoch [21/100]
#   Train Loss: 0.2863, Train Acc: 90.12%
#   Val   Loss: 0.5369, Val   Acc: 87.50%
# ✅ Checkpoint saved at epoch 21 with val_acc: 87.50%
# Epoch [22/100]
#   Train Loss: 0.3047, Train Acc: 90.38%
#   Val   Loss: 0.5109, Val   Acc: 82.50%
# Epoch [23/100]
#   Train Loss: 0.2607, Train Acc: 90.25%
#   Val   Loss: 0.6280, Val   Acc: 77.50%
# Epoch [24/100]
#   Train Loss: 0.2950, Train Acc: 89.62%
#   Val   Loss: 0.5452, Val   Acc: 77.50%
# Epoch [25/100]
#   Train Loss: 0.2725, Train Acc: 90.62%
#   Val   Loss: 0.5288, Val   Acc: 80.00%
# Epoch [26/100]
#   Train Loss: 0.3140, Train Acc: 88.38%
#   Val   Loss: 0.4999, Val   Acc: 80.00%
# Epoch [27/100]
#   Train Loss: 0.2896, Train Acc: 88.88%
#   Val   Loss: 0.3782, Val   Acc: 90.00%
# ✅ Checkpoint saved at epoch 27 with val_acc: 90.00%
# Epoch [28/100]
#   Train Loss: 0.2608, Train Acc: 90.75%
#   Val   Loss: 0.6362, Val   Acc: 82.50%
# Epoch [29/100]
#   Train Loss: 0.2566, Train Acc: 91.00%
#   Val   Loss: 0.5024, Val   Acc: 75.00%
# Epoch [30/100]
#   Train Loss: 0.2383, Train Acc: 91.62%
#   Val   Loss: 0.5468, Val   Acc: 82.50%
# Epoch [31/100]
#   Train Loss: 0.2249, Train Acc: 92.38%
#   Val   Loss: 0.5545, Val   Acc: 75.00%
# Epoch [32/100]
#   Train Loss: 0.2146, Train Acc: 92.88%
#   Val   Loss: 0.5265, Val   Acc: 82.50%
# Epoch [33/100]
#   Train Loss: 0.2899, Train Acc: 88.38%
#   Val   Loss: 0.4708, Val   Acc: 87.50%
# Epoch [34/100]
#   Train Loss: 0.2210, Train Acc: 93.00%
#   Val   Loss: 0.5441, Val   Acc: 80.00%
# Epoch [35/100]
#   Train Loss: 0.2005, Train Acc: 93.75%
#   Val   Loss: 0.4945, Val   Acc: 85.00%
# Epoch [36/100]
#   Train Loss: 0.2000, Train Acc: 94.00%
#   Val   Loss: 0.5171, Val   Acc: 80.00%
# Epoch [37/100]
#   Train Loss: 0.1949, Train Acc: 92.75%
#   Val   Loss: 0.4700, Val   Acc: 82.50%
# Epoch [38/100]
#   Train Loss: 0.1728, Train Acc: 94.12%
#   Val   Loss: 0.4431, Val   Acc: 80.00%
# Epoch [39/100]
#   Train Loss: 0.1606, Train Acc: 94.50%
#   Val   Loss: 0.4401, Val   Acc: 87.50%
# Epoch [40/100]
#   Train Loss: 0.1544, Train Acc: 95.00%
#   Val   Loss: 0.6072, Val   Acc: 77.50%
# Epoch [41/100]
#   Train Loss: 0.1826, Train Acc: 94.00%
#   Val   Loss: 0.4732, Val   Acc: 85.00%
# Epoch [42/100]
#   Train Loss: 0.1885, Train Acc: 93.62%
#   Val   Loss: 0.4969, Val   Acc: 80.00%
# Epoch [43/100]
#   Train Loss: 0.1764, Train Acc: 94.25%
#   Val   Loss: 0.3708, Val   Acc: 85.00%
# Epoch [44/100]
#   Train Loss: 0.1783, Train Acc: 94.62%
#   Val   Loss: 0.5084, Val   Acc: 82.50%
# Epoch [45/100]
#   Train Loss: 0.1684, Train Acc: 94.25%
#   Val   Loss: 0.3350, Val   Acc: 90.00%
# Epoch [46/100]
#   Train Loss: 0.1755, Train Acc: 93.88%
#   Val   Loss: 0.3395, Val   Acc: 87.50%
# Epoch [47/100]
#   Train Loss: 0.1626, Train Acc: 95.00%
#   Val   Loss: 0.3526, Val   Acc: 90.00%
# Epoch [48/100]
#   Train Loss: 0.1339, Train Acc: 96.38%
#   Val   Loss: 0.3880, Val   Acc: 87.50%
# Epoch [49/100]
#   Train Loss: 0.1635, Train Acc: 94.88%
#   Val   Loss: 0.4173, Val   Acc: 90.00%
# Epoch [50/100]
#   Train Loss: 0.1878, Train Acc: 93.88%
#   Val   Loss: 0.4003, Val   Acc: 80.00%
# Epoch [51/100]
#   Train Loss: 0.1557, Train Acc: 94.38%
#   Val   Loss: 0.4044, Val   Acc: 87.50%
# Epoch [52/100]
#   Train Loss: 0.1535, Train Acc: 94.88%
#   Val   Loss: 0.3489, Val   Acc: 90.00%
# Epoch [53/100]
#   Train Loss: 0.1564, Train Acc: 95.12%
#   Val   Loss: 0.6166, Val   Acc: 77.50%
# Epoch [54/100]
#   Train Loss: 0.1287, Train Acc: 96.12%
#   Val   Loss: 0.4224, Val   Acc: 87.50%
# Epoch [55/100]
#   Train Loss: 0.1005, Train Acc: 97.25%
#   Val   Loss: 0.3872, Val   Acc: 85.00%
# Epoch [56/100]
#   Train Loss: 0.1591, Train Acc: 95.38%
#   Val   Loss: 0.3219, Val   Acc: 90.00%
# Epoch [57/100]
#   Train Loss: 0.1351, Train Acc: 95.62%
#   Val   Loss: 0.5477, Val   Acc: 87.50%
# Epoch [58/100]
#   Train Loss: 0.1150, Train Acc: 96.38%
#   Val   Loss: 0.4011, Val   Acc: 90.00%
# Epoch [59/100]
#   Train Loss: 0.1282, Train Acc: 96.50%
#   Val   Loss: 0.4712, Val   Acc: 82.50%
# Epoch [60/100]
#   Train Loss: 0.1262, Train Acc: 95.75%
#   Val   Loss: 0.4454, Val   Acc: 85.00%
# Epoch [61/100]
#   Train Loss: 0.1078, Train Acc: 97.12%
#   Val   Loss: 0.3841, Val   Acc: 87.50%
# Epoch [62/100]
#   Train Loss: 0.1167, Train Acc: 96.25%
#   Val   Loss: 0.4207, Val   Acc: 87.50%
# Epoch [63/100]
#   Train Loss: 0.1183, Train Acc: 95.38%
#   Val   Loss: 0.3913, Val   Acc: 92.50%
# ✅ Checkpoint saved at epoch 63 with val_acc: 92.50%
# Epoch [64/100]
#   Train Loss: 0.1050, Train Acc: 96.75%
#   Val   Loss: 0.4248, Val   Acc: 87.50%
# Epoch [65/100]
#   Train Loss: 0.1129, Train Acc: 95.75%
#   Val   Loss: 0.4243, Val   Acc: 82.50%
# Epoch [66/100]
#   Train Loss: 0.0971, Train Acc: 97.12%
#   Val   Loss: 0.4604, Val   Acc: 82.50%
# Epoch [67/100]
#   Train Loss: 0.1483, Train Acc: 95.12%
#   Val   Loss: 0.5804, Val   Acc: 80.00%
# Epoch [68/100]
#   Train Loss: 0.1410, Train Acc: 94.62%
#   Val   Loss: 0.6792, Val   Acc: 87.50%
# Epoch [69/100]
#   Train Loss: 0.0893, Train Acc: 97.25%
#   Val   Loss: 0.3714, Val   Acc: 90.00%
# Epoch [70/100]
#   Train Loss: 0.0804, Train Acc: 98.38%
#   Val   Loss: 0.3832, Val   Acc: 90.00%
# Epoch [71/100]
#   Train Loss: 0.1150, Train Acc: 96.25%
#   Val   Loss: 0.3713, Val   Acc: 87.50%
# Epoch [72/100]
#   Train Loss: 0.1044, Train Acc: 96.75%
#   Val   Loss: 0.3302, Val   Acc: 87.50%
# Epoch [73/100]
#   Train Loss: 0.0875, Train Acc: 97.25%
#   Val   Loss: 0.4725, Val   Acc: 87.50%
# Epoch [74/100]
#   Train Loss: 0.0957, Train Acc: 97.00%
#   Val   Loss: 0.4034, Val   Acc: 87.50%
# Epoch [75/100]
#   Train Loss: 0.0863, Train Acc: 97.38%
#   Val   Loss: 0.3143, Val   Acc: 90.00%
# Epoch [76/100]
#   Train Loss: 0.0993, Train Acc: 97.25%
#   Val   Loss: 0.3322, Val   Acc: 90.00%
# Epoch [77/100]
#   Train Loss: 0.0763, Train Acc: 96.88%
#   Val   Loss: 0.4288, Val   Acc: 87.50%
# Epoch [78/100]
#   Train Loss: 0.0934, Train Acc: 96.88%
#   Val   Loss: 0.4420, Val   Acc: 85.00%
# Epoch [79/100]
#   Train Loss: 0.0968, Train Acc: 96.88%
#   Val   Loss: 0.4006, Val   Acc: 92.50%
# Epoch [80/100]
#   Train Loss: 0.0637, Train Acc: 98.50%
#   Val   Loss: 0.3197, Val   Acc: 90.00%
# Epoch [81/100]
#   Train Loss: 0.0704, Train Acc: 98.12%
#   Val   Loss: 0.3764, Val   Acc: 92.50%
# Epoch [82/100]
#   Train Loss: 0.0856, Train Acc: 97.62%
#   Val   Loss: 0.4456, Val   Acc: 90.00%
# Epoch [83/100]
#   Train Loss: 0.0966, Train Acc: 96.25%
#   Val   Loss: 0.4370, Val   Acc: 85.00%
# Epoch [84/100]
#   Train Loss: 0.1120, Train Acc: 95.75%
#   Val   Loss: 0.4378, Val   Acc: 87.50%
# Epoch [85/100]
#   Train Loss: 0.1128, Train Acc: 96.25%
#   Val   Loss: 0.5190, Val   Acc: 85.00%
# Epoch [86/100]
#   Train Loss: 0.0865, Train Acc: 97.38%
#   Val   Loss: 0.3822, Val   Acc: 87.50%
# Epoch [87/100]
#   Train Loss: 0.0820, Train Acc: 97.38%
#   Val   Loss: 0.4716, Val   Acc: 87.50%
# Epoch [88/100]
#   Train Loss: 0.0869, Train Acc: 97.38%
#   Val   Loss: 0.4927, Val   Acc: 82.50%
# Epoch [89/100]
#   Train Loss: 0.1057, Train Acc: 96.12%
#   Val   Loss: 0.4224, Val   Acc: 87.50%
# Epoch [90/100]
#   Train Loss: 0.0899, Train Acc: 97.62%
#   Val   Loss: 0.3304, Val   Acc: 87.50%
# Epoch [91/100]
#   Train Loss: 0.0879, Train Acc: 97.00%
#   Val   Loss: 0.4216, Val   Acc: 85.00%
# Epoch [92/100]
#   Train Loss: 0.0987, Train Acc: 96.38%
#   Val   Loss: 0.5523, Val   Acc: 80.00%
# Epoch [93/100]
#   Train Loss: 0.0686, Train Acc: 98.12%
#   Val   Loss: 0.3931, Val   Acc: 82.50%
# Epoch [94/100]
#   Train Loss: 0.0750, Train Acc: 97.12%
#   Val   Loss: 0.3003, Val   Acc: 90.00%
# Epoch [95/100]
#   Train Loss: 0.0736, Train Acc: 98.12%
#   Val   Loss: 0.4014, Val   Acc: 87.50%
# Epoch [96/100]
#   Train Loss: 0.0472, Train Acc: 98.62%
#   Val   Loss: 0.4245, Val   Acc: 85.00%
# Epoch [97/100]
#   Train Loss: 0.0563, Train Acc: 98.38%
#   Val   Loss: 0.3993, Val   Acc: 90.00%
# Epoch [98/100]
#   Train Loss: 0.0802, Train Acc: 97.00%
#   Val   Loss: 0.3642, Val   Acc: 87.50%
# Epoch [99/100]
#   Train Loss: 0.0798, Train Acc: 97.88%
#   Val   Loss: 0.4656, Val   Acc: 87.50%
# Epoch [100/100]
#   Train Loss: 0.0675, Train Acc: 98.50%
#   Val   Loss: 0.3157, Val   Acc: 85.00%
# Loading best model for final validation...
# C:\Users\Vyshnav Kumar\AppData\Local\Temp\ipykernel_17236\3379027944.py:229: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(save_path)['model_state_dict'])
# Final Test Accuracy of Best Model: 92.50%
# Final Test Loss of Best Model: 0.3913

# %%
from torchsummary import summary

# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = FaceRecognitionModel(num_classes=len(train_dataset.classes)).to(device)

# Print summary (assuming input image size is 3 x 128 x 128)
summary(model, input_size=(3, 128, 128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 128, 128]             896
#        BatchNorm2d-2         [-1, 32, 128, 128]              64
#               ReLU-3         [-1, 32, 128, 128]               0
#          MaxPool2d-4           [-1, 32, 64, 64]               0
#            Dropout-5           [-1, 32, 64, 64]               0
#             Conv2d-6           [-1, 64, 64, 64]          18,496
#        BatchNorm2d-7           [-1, 64, 64, 64]             128
#               ReLU-8           [-1, 64, 64, 64]               0
#          MaxPool2d-9           [-1, 64, 32, 32]               0
#           Dropout-10           [-1, 64, 32, 32]               0
#            Conv2d-11          [-1, 128, 32, 32]          73,856
#       BatchNorm2d-12          [-1, 128, 32, 32]             256
#              ReLU-13          [-1, 128, 32, 32]               0
#         MaxPool2d-14          [-1, 128, 16, 16]               0
#           Dropout-15          [-1, 128, 16, 16]               0
#            Linear-16             [-1, 256, 384]          49,152
#            Linear-17             [-1, 256, 384]          49,152
#            Linear-18             [-1, 256, 128]          16,512
#    CrossAttention-19          [-1, 128, 16, 16]               0
#           Sigmoid-20          [-1, 128, 16, 16]               0
#  ChannelAttention-21          [-1, 128, 16, 16]               0
#            Linear-22             [-1, 256, 384]          49,152
#            Linear-23             [-1, 256, 384]          49,152
#            Linear-24             [-1, 256, 128]          16,512
#    CrossAttention-25          [-1, 128, 16, 16]               0
#            Conv2d-26            [-1, 1, 16, 16]           6,273
#           Sigmoid-27            [-1, 1, 16, 16]               0
#  SpatialAttention-28          [-1, 128, 16, 16]               0
#           CA_CBAM-29          [-1, 128, 16, 16]               0
# AdaptiveAvgPool2d-30            [-1, 128, 1, 1]               0
#           Dropout-31                  [-1, 128]               0
#            Linear-32                    [-1, 4]             516
# ================================================================
# Total params: 330,117
# Trainable params: 330,117
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 29.51
# Params size (MB): 1.26
# Estimated Total Size (MB): 30.95
# ----------------------------------------------------------------
